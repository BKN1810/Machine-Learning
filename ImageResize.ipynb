# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
DATADIR="D:/Dataset/Covid-19 and Pneumonia Dataset"
CATEGORIES=["bacterial_pneumonia","covid-19","normal","viral_pneumonia"]

# %%
for category in CATEGORIES:
    path= os.path.join(DATADIR,category)
    for img in os.listdir(path):
        img_array= cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
        #print(str(img_array))
        plt.imshow(img_array,cmap="gray")
        plt.show()
        break
    break

# %%
print(img_array.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0cbba2a0abf3> in <module>
# ----> 1 print(img_array.shape)
#
# NameError: name 'img_array' is not defined

# %%
IMG_SIZE=512
i=1
new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
cv2.imwrite("D:/Dataset/Covid-19/normal_" + "img_%04i.jpg"%i, new_array)
plt.imshow(new_array,cmap="gray")
print(new_array.shape)
# Out:
# (512, 512)

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

IMG_SIZE=128

DATADIR="F:/Gray2Color_Mixed_Dataset/test_data"
#CATEGORIES=["nw1","nw2"]

resize_image=[]
def create_resize_image():
    i=0
    path= os.path.join(DATADIR) # 0 for normal and 1 for PNEUMONIA
    #class_num=CATEGORIES.index(category)
    for img in os.listdir(path):
        img_array= cv2.imread(os.path.join(path,img))
        new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
        cv2.imwrite("F:/Gray2Color_Mixed_Dataset/ab/gray2rgb_" + "_%05i.jpg"%i, new_array)
        #plt.imshow(new_array,cmap="gray")
        #print(new_array.shape)
        i+=1
                
create_resize_image()

# %%
DATADIR="D:/Dataset/NW/train/nw1"
#CATEGORIES=["nw1","nw2"]

resize_image=[]
def create_resize_image():
    i=1
    for category in CATEGORIES:
        #path= os.path.join(DATADIR,category) # 0 for normal and 1 for PNEUMONIA
        path= os.path.join(DATADIR) # 0 for normal and 1 for PNEUMONIA
        class_num=CATEGORIES.index(category)
        for img in os.listdir(path):
                
                img_array= cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
                
                new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
                cv2.imwrite("D:/Dataset/NW/train/normal/normal_" + "img_%04i.jpg"%i, new_array)
                #plt.imshow(new_array,cmap="gray")
                #print(new_array.shape)
                i+=1
                
create_resize_image()

# %%
DATADIR="D:/Dataset/NW/train/nw2"
#CATEGORIES=["nw1","nw2"]

resize_image=[]
def create_resize_image():
    i=1
    for category in CATEGORIES:
        #path= os.path.join(DATADIR,category) # 0 for normal and 1 for PNEUMONIA
        path= os.path.join(DATADIR) # 0 for normal and 1 for PNEUMONIA
        class_num=CATEGORIES.index(category)
        for img in os.listdir(path):
                
                img_array= cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
                
                new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
                cv2.imwrite("D:/Dataset/NW/train/pneumonia/pneumonia_" + "img_%04i.jpg"%i, new_array)
                #plt.imshow(new_array,cmap="gray")
                #print(new_array.shape)
                i+=1
                
create_resize_image()
