# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
IMG_SIZE=224
i=1
img_array= cv2.imread(os.path.join("D:/Dataset/Dog_Cat_Dataset/test_set/cats","cat.4001.jpg"),cv2.IMREAD_UNCHANGED)
new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
cv2.imwrite("D:/Dataset/Dog_Cat_Dataset/test_set/cat" + "_%04i.jpg"%i, new_array)
plt.imshow(new_array)
print(new_array.shape)
# Out:
# (224, 224, 3)

# %%
DATADIR="D:/Dataset/Dog_Cat_Dataset/test_set"
CATEGORIES=["cats","dogs"]

resize_image=[]
def create_resize_image():
    i=1
    for category in CATEGORIES:
        path= os.path.join(DATADIR,category) # 0 for normal and 1 for PNEUMONIA
        #path= os.path.join(DATADIR) # 0 for normal and 1 for PNEUMONIA
        class_num=CATEGORIES.index(category)
        for img in os.listdir(path):
                img_array= cv2.imread(os.path.join(path,img),cv2.IMREAD_UNCHANGED)
                new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
                if i<=1000:
                    cv2.imwrite("D:/Dataset/Dog_Cat_Dataset/testSet/cats/cat" + "_%04i.jpg"%i, new_array)
                else:
                    cv2.imwrite("D:/Dataset/Dog_Cat_Dataset/testSet/dogs/dog" + "_%04i.jpg"%i, new_array)
                #plt.imshow(new_array)
                #print(new_array.shape)
                i+=1
                
create_resize_image()
# Out:
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# ...

# %%
DATADIR="D:/Dataset/Dog_Cat_Dataset/training_set"
CATEGORIES=["cats","dogs"]

resize_image=[]
def create_resize_image():
    i=1
    for category in CATEGORIES:
        path= os.path.join(DATADIR,category) # 0 for normal and 1 for PNEUMONIA
        #path= os.path.join(DATADIR) # 0 for normal and 1 for PNEUMONIA
        class_num=CATEGORIES.index(category)
        for img in os.listdir(path):
                img_array= cv2.imread(os.path.join(path,img),cv2.IMREAD_UNCHANGED)
                new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
                if i<=4000:
                    cv2.imwrite("D:/Dataset/Dog_Cat_Dataset/trainingSet/cats/cat" + "_%04i.jpg"%i, new_array)
                else:
                    cv2.imwrite("D:/Dataset/Dog_Cat_Dataset/trainingSet/dogs/dog" + "_%04i.jpg"%i, new_array)
                #plt.imshow(new_array)
                #print(new_array.shape)
                i+=1
                
create_resize_image()
